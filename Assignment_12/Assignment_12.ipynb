# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 159 (delta 0), reused 1 (delta 0), pack-reused 156
# Receiving objects: 100% (159/159), 12.75 MiB | 28.31 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !pip install gdown

# %%
import os

# %%
os.chdir("/content/YoloV3/weights")

# %%
# !gdown --id 1vRDkpAiNdqHORTUImkrpD7kK_DkCcMus
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1vRDkpAiNdqHORTUImkrpD7kK_DkCcMus
# From (redirected): https://drive.google.com/uc?id=1vRDkpAiNdqHORTUImkrpD7kK_DkCcMus&confirm=t&uuid=ac151572-54be-4756-b0d8-759deac05765
# To: /content/YoloV3/weights/yolov3-spp-ultralytics.pt
# 100% 252M/252M [00:02<00:00, 116MB/s]

# %%
os.chdir("/content/YoloV3")

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 100 --nosave
# Out:
# Namespace(epochs=100, batch_size=20, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-23 09:51:38.431278: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-23 09:51:38.431347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python detect.py --cfg cfg/yolov3-custom.cfg --weights weights/last.pt
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='data/customdata/images', output='output', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/101 data/customdata/images/Image-1.jpg: 384x512 1 tigers, Done. (0.047s)
# image 2/101 data/customdata/images/Image-10.jpg: 320x512 2 tigers, Done. (0.066s)
# ...

# %%
# !zip -r /content/output.zip /content/YoloV3/output
# Out:
#   adding: content/YoloV3/output/ (stored 0%)
#   adding: content/YoloV3/output/Image-60.jpg (deflated 1%)
#   adding: content/YoloV3/output/Image-21.jpg (deflated 0%)
#   adding: content/YoloV3/output/Image-63.jpg (deflated 1%)
#   adding: content/YoloV3/output/Image-72.jpg (deflated 4%)
#   adding: content/YoloV3/output/Image-83.jpg (deflated 5%)
#   adding: content/YoloV3/output/Image-99.jpg (deflated 3%)
#   adding: content/YoloV3/output/Image-64.jpg (deflated 6%)
#   adding: content/YoloV3/output/Image-115.jpg (deflated 1%)
#   adding: content/YoloV3/output/Image-103.jpg (deflated 0%)
#   adding: content/YoloV3/output/Image-116.jpg (deflated 4%)
#   adding: content/YoloV3/output/Image-90.jpg (deflated 0%)
#   adding: content/YoloV3/output/Image-70.jpg (deflated 0%)
#   adding: content/YoloV3/output/Image-93.jpg (deflated 9%)
#   adding: content/YoloV3/output/Image-59.jpg (deflated 3%)
#   adding: content/YoloV3/output/Image-112.jpg (deflated 9%)
# ...
